# %% [markdown]
# Análise dos Microdados do Enem

# %%
import pandas as pd

# %%
microdadosEnem = pd.read_csv("C:/Users/mauri/Desktop/Análise de Dados/microdados_enem_2023/DADOS/MICRODADOS_ENEM_2023.csv", sep=";", encoding='ISO-8859-1')

# %%
microdadosEnem.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210059085136    2023               14       M                2
# 1  210059527735    2023               12       M                2
# 2  210061103945    2023                6       F                1
# 3  210060214087    2023                2       F                1
# 4  210059980948    2023                3       F                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            1                 1                1               17          1
# 1            1                 0                1               16          1
# 2            1                 1                1                0          1
# 3            3                 1                2                0          2
# 4            3                 1                2                0          2
#
#    ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025
# ...

# %%
microdadosEnem.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
#        'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
# ...

# %%
colunasSelecionadasEnem = ['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
       'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
       'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
       'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
       'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
       'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
       'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
       'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
       'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
       'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
       'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
       'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
       'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
       'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
       'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006',
       'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014',
       'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022',
       'Q023', 'Q024', 'Q025']

# %%
microdadosEnemSelecionado = microdadosEnem.filter(items=colunasSelecionadasEnem)

# %%
microdadosEnemSelecionado.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210059085136    2023               14       M                2
# 1  210059527735    2023               12       M                2
# 2  210061103945    2023                6       F                1
# 3  210060214087    2023                2       F                1
# 4  210059980948    2023                3       F                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            1                 1                1               17          1
# 1            1                 0                1               16          1
# 2            1                 1                1                0          1
# 3            3                 1                2                0          2
# 4            3                 1                2                0          2
#
#    ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025
# ...

# %%
microdadosEnem[0:100]
# Out:
#     NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0   210059085136    2023               14       M                2
# 1   210059527735    2023               12       M                2
# 2   210061103945    2023                6       F                1
# 3   210060214087    2023                2       F                1
# 4   210059980948    2023                3       F                1
# ..           ...     ...              ...     ...              ...
# 95  210059246972    2023                9       M                1
# 96  210061234981    2023                7       M                4
# 97  210061327761    2023                4       F                1
# 98  210059587846    2023                2       M                1
# 99  210058941492    2023                2       F                1
#
#     TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 0             1                 1                1               17
# ...

# %%
microdadosEnem.iloc[0:100]
# Out:
#     NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0   210059085136    2023               14       M                2
# 1   210059527735    2023               12       M                2
# 2   210061103945    2023                6       F                1
# 3   210060214087    2023                2       F                1
# 4   210059980948    2023                3       F                1
# ..           ...     ...              ...     ...              ...
# 95  210059246972    2023                9       M                1
# 96  210061234981    2023                7       M                4
# 97  210061327761    2023                4       F                1
# 98  210059587846    2023                2       M                1
# 99  210058941492    2023                2       F                1
#
#     TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 0             1                 1                1               17
# ...

# %%
microdadosEnem.iloc[0:100, :3]
# Out:
#     NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA
# 0   210059085136    2023               14
# 1   210059527735    2023               12
# 2   210061103945    2023                6
# 3   210060214087    2023                2
# 4   210059980948    2023                3
# ..           ...     ...              ...
# 95  210059246972    2023                9
# 96  210061234981    2023                7
# 97  210061327761    2023                4
# 98  210059587846    2023                2
# 99  210058941492    2023                2
#
# [100 rows x 3 columns]

# %%
coluna_no_municipio_residencia = microdadosEnemSelecionado['NO_MUNICIPIO_ESC']

# %%
coluna_no_municipio_residencia
# Out:
# 0                NaN
# 1                NaN
# 2                NaN
# 3          Fortaleza
# 4            Quixadá
#              ...
# 3933950          NaN
# 3933951          NaN
# 3933952          NaN
# 3933953          NaN
# 3933954       Osasco
# Name: NO_MUNICIPIO_ESC, Length: 3933955, dtype: object

# %%
coluna_no_municipio_residencia.value_counts()
# Out:
# NO_MUNICIPIO_ESC
# São Paulo          45215
# Fortaleza          27634
# Rio de Janeiro     26064
# Brasília           20113
# Manaus             15500
#                    ...
# Novo Jardim            1
# Tupiratins             1
# Augusto de Lima        1
# Água Comprida          1
# Ubiretama              1
# Name: count, Length: 5261, dtype: int64

# %%
coluna_no_municipio_residencia.value_counts().sort_index()
# Out:
# NO_MUNICIPIO_ESC
# Abadia de Goiás         55
# Abadia dos Dourados     18
# Abadiânia              152
# Abaetetuba             878
# Abaeté                  65
#                       ...
# Áurea                    4
# Ângulo                   4
# Érico Cardoso           27
# Óbidos                 124
# Óleo                     5
# Name: count, Length: 5261, dtype: int64

# %%
coluna_no_municipio_residencia.value_counts().sort_index().nlargest(10)
# Out:
# NO_MUNICIPIO_ESC
# São Paulo         45215
# Fortaleza         27634
# Rio de Janeiro    26064
# Brasília          20113
# Manaus            15500
# Curitiba          11491
# Goiânia           10835
# Belo Horizonte    10302
# Salvador           9727
# Recife             9620
# Name: count, dtype: int64

# %%
coluna_nu_faixa_etaria = microdadosEnemSelecionado['TP_FAIXA_ETARIA']

# %%
coluna_nu_faixa_etaria.head()
# Out:
# 0    14
# 1    12
# 2     6
# 3     2
# 4     3
# Name: TP_FAIXA_ETARIA, dtype: int64

# %%
coluna_nu_faixa_etaria.hist(bins=30)
# Out:
# <Axes: >

# %%
coluna_in_estado_civil = microdadosEnemSelecionado['TP_ESTADO_CIVIL']

# %%
coluna_in_estado_civil.value_counts()
# Out:
# TP_ESTADO_CIVIL
# 1    3491857
# 2     200456
# 0     171900
# 3      64933
# 4       4809
# Name: count, dtype: int64

# %%
coluna_tp_sexo = microdadosEnemSelecionado['TP_SEXO']

# %%
distTpSexo = coluna_tp_sexo.value_counts()

# %%
distTpSexo
# Out:
# TP_SEXO
# F    2411185
# M    1522770
# Name: count, dtype: int64

# %%
percentInSexo = [100*x/distTpSexo.sum() for x in distTpSexo]

# %%
percentInSexo
# Out:
# [np.float64(61.291626365832855), np.float64(38.708373634167145)]

# %%
percentInSexo[0]
# Out:
# np.float64(61.29)

# %%
percentInSexo = [round(100*x/distTpSexo.sum(), 2) for x in distTpSexo]

# %%
percentInSexo
# Out:
# [np.float64(61.29), np.float64(38.71)]

# %%
colunasSelecionadas = ['NU_NOTA_REDACAO', 'TP_SEXO']

# %%
microdadosEnemSexoRedacao = microdadosEnem.filter(items=colunasSelecionadas).dropna()

# %%
microdadosEnemSexoRedacao.head()
# Out:
#     NU_NOTA_REDACAO TP_SEXO
# 2             700.0       F
# 3             880.0       F
# 4             560.0       F
# 9             600.0       M
# 10            860.0       M

# %%
microdadosEnemSexoRedacao.groupby('TP_SEXO').count()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                1734314
# M                1088329

# %%
microdadosEnemSexoRedacao.groupby('TP_SEXO').max()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                 1000.0
# M                 1000.0

# %%
microdadosEnemSexoRedacao.groupby('TP_SEXO').min()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                    0.0
# M                    0.0

# %%
microdadosEnemSexoRedacao[microdadosEnemSexoRedacao.NU_NOTA_REDACAO>0].groupby('TP_SEXO').min()
# Out:
#          NU_NOTA_REDACAO
# TP_SEXO
# F                   40.0
# M                   40.0

# %%
microdadosEnemSexoRedacao.groupby('TP_SEXO').describe()
# Out:
#         NU_NOTA_REDACAO                                                    \
#                   count        mean         std  min    25%    50%    75%
# TP_SEXO
# F             1734314.0  634.928600  211.442302  0.0  520.0  640.0  800.0
# M             1088329.0  590.500667  216.812604  0.0  480.0  600.0  740.0
#
#
#             max
# TP_SEXO
# F        1000.0
# M        1000.0
